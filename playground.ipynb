# %%
from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole

# %%
# mol = Chem.MolFromSmiles('CN(C)c1ccccc1')
# matches = mol.GetSubstructMatches(Chem.MolFromSmarts('c:@c'))
# match_idxs = set()
# for match in matches:
#     match_idxs.update(match)

mol

# %%
mol = Chem.MolFromSmiles('CC(C)(C#CC1=NC(=C(C=C1)C2=C3C(=C(C=C2)Cl)C(=NN3CC(F)(F)F)NS(=O)(=O)C)C(CC4=CC(=CC(=C4)F)F)NC(=O)CN5C6=C(C7CC7C6(F)F)C(=N5)C(F)(F)F)S(=O)(=O)C')

mol
